# %%
# Import of libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Load the data
df = pd.read_csv("../data/BankChurners_CleanedMapped.csv", index_col="ClientID")
df.head()
# Out:
#            Attrited  Age  Gender  DependentCount  EducationLevel  \
# ClientID
# 768805383         0   45       0               3               2
# 818770008         0   49       1               5               4
# 713982108         0   51       0               3               4
# 769911858         0   40       1               4               2
# 709106358         0   40       0               3               1
#
#            MaritalStatus  IncomeCategory  CardCategory  \
# ClientID
# 768805383              2               3             1
# 818770008              1               1             1
# 713982108              2               4             1
# 769911858              0               1             1
# 709106358              2               3             1
#
#            RelationshipPeriod_InMonths  TotalProductNo  \
# ClientID
# 768805383                           39               5
# 818770008                           44               6
# 713982108                           36               4
# 769911858                           34               3
# 709106358                           21               5
#
#            MonthsInactive_Last12Months  ContactNo_Last12Months  CreditLimit  \
# ClientID
# 768805383                            1                       3      12691.0
# 818770008                            1                       2       8256.0
# 713982108                            1                       0       3418.0
# 769911858                            4                       1       3313.0
# 709106358                            1                       0       4716.0
#
#            TotalRevolvingBalance_CC  OpenToBuyAve_Last12Months  \
# ClientID
# 768805383                       777                    11914.0
# 818770008                       864                     7392.0
# 713982108                         0                     3418.0
# 769911858                      2517                      796.0
# 709106358                         0                     4716.0
#
#            TransactionAmount_ChangeQ4overQ1  \
# ClientID
# 768805383                             1.335
# 818770008                             1.541
# 713982108                             2.594
# 769911858                             1.405
# 709106358                             2.175
#
#            TotalTransactionAmount_Last12Months  \
# ClientID
# 768805383                                 1144
# 818770008                                 1291
# 713982108                                 1887
# 769911858                                 1171
# 709106358                                  816
#
#            TotalTransactionCount_Last12Months  \
# ClientID
# 768805383                                  42
# 818770008                                  33
# 713982108                                  20
# 769911858                                  20
# 709106358                                  28
#
#            TransactionCount_ChangeQ4overQ1  AveCardUtilizationRatio
# ClientID
# 768805383                            1.625                    0.061
# 818770008                            3.714                    0.105
# 713982108                            2.333                    0.000
# 769911858                            2.333                    0.760
# 709106358                            2.500                    0.000
